# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics

# %%
# load in CSV
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
# Set x-axis and tick locations
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind ='bar')
plt.show()

# %%
stdev = pyber_ride_df.std(y)
stdev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-dc624d809221> in <module>
# ----> 1 stdev = pyber_ride_df.std(y)
#       2 stdev
#
# NameError: name 'y' is not defined

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind ='bar', color = 'skyblue')
plt.errorbar(x="Month", y="Avg. Fare ($USD)", yerr=stdev, capsize=3)
plt.xticks(x="Month", rotation='horizontal')
plt.yticks(np.arange(0, 60, step=5.0))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-44d4fd711f03> in <module>
#       1 pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind ='bar', color = 'skyblue')
# ----> 2 plt.errorbar(x="Month", y="Avg. Fare ($USD)", yerr=stdev, capsize=3)
#       3 plt.xticks(x="Month", rotation='horizontal')
#       4 plt.yticks(np.arange(0, 60, step=5.0))
#       5 plt.show()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2527         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2528         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
# -> 2529         **({"data": data} if data is not None else {}), **kwargs)
#    2530
#    2531
#
# ...
